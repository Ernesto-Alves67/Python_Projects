# %%
import pandas as pd

file = 'TA_PRECO_MEDICAMENTO.csv'
import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
df = pd.read_csv(file, encoding='Windows-1252', sep=';')

# %%
print(df)
# Out:
#                                               SUBSTÂNCIA                CNPJ  \
# 0      SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  33.379.884/0001-96
# 1                       DIENOGESTE;VALERATO DE ESTRADIOL  56.990.534/0001-67
# 2                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  45.987.013/0001-34
# 3                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  45.987.013/0001-34
# 4                                           MONTELUCASTE  45.987.013/0001-34
# ...                                                  ...                 ...
# 26305                            CLORIDRATO DE SEVELÂMER  13.078.518/0001-90
# 26306                                    INSULINA HUMANA  13.078.518/0001-90
# 26307                                    INSULINA HUMANA  13.078.518/0001-90
# 26308                                ISOCONAZOL;ABARELIX  33.683.202/0001-34
# 26309                                 VALPROATO DE SÓDIO  49.475.833/0001-06
#
# ...

# %%
print(df.columns)
# Out:
# Index(['SUBSTÂNCIA', 'CNPJ', 'LABORATÓRIO', 'CÓDIGO GGREM', 'REGISTRO',
#        'EAN 1', 'EAN 2', 'EAN 3', 'PRODUTO', 'APRESENTAÇÃO',
#        'CLASSE TERAPÊUTICA', 'TIPO DE PRODUTO (STATUS DO PRODUTO)',
#        'REGIME DE PREÇO', 'PF Sem Impostos', 'PF 0%', 'PF 12%', 'PF 17%',
#        'PF 17% ALC', 'PF 17,5%', 'PF 17,5% ALC', 'PF 18%', 'PF 18% ALC',
#        'PF 20%', 'PMC 0%', 'PMC 12%', 'PMC 17%', 'PMC 17% ALC', 'PMC 17,5%',
#        'PMC 17,5% ALC', 'PMC 18%', 'PMC 18% ALC', 'PMC 20%',
#        'RESTRIÇÃO HOSPITALAR', 'CAP', 'CONFAZ 87', 'ICMS 0%',
#        'ANÁLISE RECURSAL',
#        'LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)',
#        'COMERCIALIZAÇÃO 2020', 'TARJA'],
#       dtype='object')

# %%
##Filtragemn

# %%
print(df[['TARJA', 'PRODUTO']][0:15])
# Out:
#                 TARJA       PRODUTO
# 0          Tarja -(*)  TALCO ALÍVIO
# 1   Tarja Vermelha(*)     CHARMELIE
# 2     Tarja  Vermelha    CO-RENITEC
# 3     Tarja  Vermelha    CO-RENITEC
# 4     Tarja  Vermelha     SINGULAIR
# 5     Tarja  Vermelha     SINGULAIR
# 6     Tarja  Vermelha     SINGULAIR
# 7     Tarja  Vermelha     SINGULAIR
# 8     Tarja  Vermelha     SINGULAIR
# 9     Tarja  Vermelha     SINGULAIR
# 10  Tarja Vermelha(*)     SINGULAIR
# 11  Tarja Vermelha(*)     SINGULAIR
# 12    Tarja  Vermelha        COZAAR
# 13    Tarja  Vermelha        COZAAR
# 14    Tarja  Vermelha        COZAAR

# %%
print(df.iloc[0:10])
# Out:
#                                           SUBSTÂNCIA                CNPJ  \
# 0  SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  33.379.884/0001-96
# 1                   DIENOGESTE;VALERATO DE ESTRADIOL  56.990.534/0001-67
# 2             HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  45.987.013/0001-34
# 3             HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  45.987.013/0001-34
# 4                                       MONTELUCASTE  45.987.013/0001-34
# 5                                       MONTELUCASTE  45.987.013/0001-34
# 6                                       MONTELUCASTE  45.987.013/0001-34
# 7                                       MONTELUCASTE  45.987.013/0001-34
# 8                                       MONTELUCASTE  45.987.013/0001-34
# 9                                       MONTELUCASTE  45.987.013/0001-34
#
#                                       LABORATÓRIO     CÓDIGO GGREM  \
# 0                        LABORATORIO SIMOES LTDA.  520500901178410
# ...

# %%
df.loc[df['PRODUTO'].str.contains('VACINA')]
# Out:
#                                               SUBSTÂNCIA                CNPJ  \
# 30                                     VIRUS DA VARICELA  45.987.013/0001-34
# 31                                     VIRUS DA VARICELA  45.987.013/0001-34
# 3599                                          VACINA BCG  33.485.939/0001-42
# 3600                                          VACINA BCG  33.485.939/0001-42
# 13190                         VÍRUS 17D DA FEBRE AMARELA  33.781.055/0001-35
# 13191                         VÍRUS 17D DA FEBRE AMARELA  33.781.055/0001-35
# 13207                              VACINA CONTRA SARAMPO  33.781.055/0001-35
# 13215  VACINA HAEMOPHILUS INFLUENZAE B (CONJUGADA) E ...  33.781.055/0001-35
# 13224                          ROTAVÍRUS HUMANO ATENUADO  33.781.055/0001-35
# 13227  POLISSACARÍDEO CONJUGADO DE STREPTOCOCCUS PNEU...  33.781.055/0001-35
# 13244  VÍRUS DA CAXUMBA;VÍRUS DA RUBEOLA;VÍRUS DO SAR...  33.781.055/0001-35
# ...
